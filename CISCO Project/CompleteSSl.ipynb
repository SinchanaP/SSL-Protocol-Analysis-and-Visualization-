# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Dataset1 = pd.read_csv("SSlPackets.csv")
Dataset2 = pd.read_csv("myData.csv")
Dataset3 = pd.read_csv("Dataset3.csv")

# %%
Dataset1.head(100)
# Out:
#      No.       Time                                   Source  \
# 0     11   0.924766                      2606:4700::6812:acf
# 1     16   1.536066  2401:4900:4a64:d98f:6928:c4c0:d81b:3a08
# 2     17   2.007463                      2606:4700::6812:acf
# 3     19   3.010786                      2606:4700::6812:acf
# 4     21   3.011544                      2606:4700::6812:acf
# ..   ...        ...                                      ...
# 95  1969  17.598032                     2606:4700::6810:125e
# 96  1972  17.600261                     2606:4700::6810:125e
# 97  1974  17.602573                     2606:4700::6810:125e
# 98  1976  17.604831                     2606:4700::6810:125e
# 99  1978  17.606009                     2606:4700::6810:125e
#
#                                 Destination Protocol  Length  \
# 0   2401:4900:4a64:d98f:6928:c4c0:d81b:3a08  TLSv1.2    1434
# 1                  2404:6800:4007:82b::200e  TLSv1.2    1493
# ...

# %%
Dataset2.head(100)
# Out:
#      No.       Time                                   Source  \
# 0      3   1.339396  2401:4900:336e:c512:f0c3:5fcb:e314:92cc
# 1      5   2.046871        2a03:2880:f268:c1:face:b00c:0:167
# 2      9   4.913429        2a03:2880:f268:c1:face:b00c:0:167
# 3    152  10.955059  2401:4900:336e:c512:f0c3:5fcb:e314:92cc
# 4    174  11.159039                     2606:4700::6810:125e
# ..   ...        ...                                      ...
# 95  1928  20.143316                            13.234.159.72
# 96  1936  20.153673                            13.234.159.72
# 97  1940  20.158984                            13.234.159.72
# 98  1949  20.176247                            13.234.159.72
# 99  1953  20.181735                            13.234.159.72
#
#                                 Destination Protocol  Length  \
# 0         2a03:2880:f268:c1:face:b00c:0:167  TLSv1.2     117
# 1   2401:4900:336e:c512:f0c3:5fcb:e314:92cc  TLSv1.2     124
# ...

# %%
Dataset3.head(100)
# Out:
#     No.      Time                                   Source  \
# 0    11  0.131049  2401:4900:336e:c512:4483:aa80:d7d1:cdff
# 1    15  0.239899                 2404:6800:4007:816::2003
# 2    20  0.244521                 2404:6800:4007:816::2003
# 3    25  0.253923  2401:4900:336e:c512:4483:aa80:d7d1:cdff
# 4    26  0.254129  2401:4900:336e:c512:4483:aa80:d7d1:cdff
# ..  ...       ...                                      ...
# 95  725  9.039660                            192.168.43.63
# 96  726  9.040941                            192.168.43.63
# 97  730  9.098061                            192.168.43.63
# 98  734  9.105482                            192.168.43.63
# 99  744  9.140011                            192.168.43.63
#
#                                 Destination Protocol  Length  \
# 0                  2404:6800:4007:816::2003  TLSv1.3     603
# 1   2401:4900:336e:c512:4483:aa80:d7d1:cdff  TLSv1.3    1294
# 2   2401:4900:336e:c512:4483:aa80:d7d1:cdff  TLSv1.3     695
# ...

# %%
Dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13945 entries, 0 to 13944
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No.          13945 non-null  int64
#  1   Time         13945 non-null  float64
#  2   Source       13945 non-null  object
#  3   Destination  13945 non-null  object
#  4   Protocol     13945 non-null  object
#  5   Length       13945 non-null  int64
#  6   Info         13945 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 762.7+ KB

# %%
Dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No.          194 non-null    int64
#  1   Time         194 non-null    float64
#  2   Source       194 non-null    object
#  3   Destination  194 non-null    object
#  4   Protocol     194 non-null    object
#  5   Length       194 non-null    int64
#  6   Info         194 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 10.7+ KB

# %%
Dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No.          194 non-null    int64
#  1   Time         194 non-null    float64
#  2   Source       194 non-null    object
#  3   Destination  194 non-null    object
#  4   Protocol     194 non-null    object
#  5   Length       194 non-null    int64
#  6   Info         194 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 10.7+ KB

# %%
some_values1 = ['192.168.42.57','23.111.9.35']
SSlDataset1 = Dataset1.loc[Dataset1['Source'].isin(some_values1)]

some_values2 = ['13.234.159.72','192.168.43.63']
SSlDataset2 = Dataset2.loc[Dataset2['Source'].isin(some_values2)]

some_values3 = ['192.168.43.63','114.29.220.99']
SSlDataset3 = Dataset3.loc[Dataset3['Source'].isin(some_values3)]

# %%
SSlDataset1
# Out:
#          No.        Time         Source     Destination Protocol  Length  \
# 24       279    3.970100  192.168.42.57     23.111.9.35  TLSv1.2     571
# 25       282    3.971079  192.168.42.57     23.111.9.35  TLSv1.2     571
# 27       420    4.143166    23.111.9.35   192.168.42.57  TLSv1.2    1514
# 28       424    4.183122    23.111.9.35   192.168.42.57  TLSv1.2    1514
# 29       450    4.311076    23.111.9.35   192.168.42.57  TLSv1.2    1514
# ...      ...         ...            ...             ...      ...     ...
# 13873  70772  812.956600  192.168.42.57  142.250.76.174  TLSv1.3     533
# 13876  70783  813.019712  192.168.42.57  142.250.76.174  TLSv1.3      97
# 13881  70793  813.088140  192.168.42.57  142.250.76.174  TLSv1.3     105
# 13926  73210  827.206113  192.168.42.57   35.186.224.46  TLSv1.3     109
# 13927  73389  834.795593  192.168.42.57   35.186.224.47  TLSv1.2     101
#
#                                                  Info
# ...

# %%
SSlDataset2
# Out:
#       No.       Time         Source    Destination Protocol  Length  \
# 35    616  16.981262  192.168.43.63  13.234.159.72  TLSv1.2     583
# 36    659  17.037166  192.168.43.63  13.234.159.72  TLSv1.2     583
# 37    684  17.059165  13.234.159.72  192.168.43.63  TLSv1.2    1514
# 38    697  17.074081  13.234.159.72  192.168.43.63  TLSv1.2     680
# 39    701  17.078898  192.168.43.63  13.234.159.72  TLSv1.2     192
# ..    ...        ...            ...            ...      ...     ...
# 189  2245  25.389944  13.234.159.72  192.168.43.63  TLSv1.2      97
# 190  2249  25.390171  13.234.159.72  192.168.43.63  TLSv1.2      97
# 191  2252  25.391391  13.234.159.72  192.168.43.63  TLSv1.2      97
# 192  2259  25.467988  13.234.159.72  192.168.43.63  TLSv1.2      97
# 193  2263  25.697265  13.234.159.72  192.168.43.63  TLSv1.2      97
#
#                                                   Info
# 35                                        Client Hello
# ...

# %%
SSlDataset1['Protocol']
# Out:
# 24       TLSv1.2
# 25       TLSv1.2
# 27       TLSv1.2
# 28       TLSv1.2
# 29       TLSv1.2
#           ...
# 13873    TLSv1.3
# 13876    TLSv1.3
# 13881    TLSv1.3
# 13926    TLSv1.3
# 13927    TLSv1.2
# Name: Protocol, Length: 743, dtype: object

# %%
SSlDataset2['Protocol']
# Out:
# 35     TLSv1.2
# 36     TLSv1.2
# 37     TLSv1.2
# 38     TLSv1.2
# 39     TLSv1.2
#         ...
# 189    TLSv1.2
# 190    TLSv1.2
# 191    TLSv1.2
# 192    TLSv1.2
# 193    TLSv1.2
# Name: Protocol, Length: 110, dtype: object

# %%
SSlDataset3['Protocol']
# Out:
# 18     TLSv1.2
# 19     TLSv1.2
# 20     TLSv1.2
# 21     TLSv1.2
# 22     TLSv1.2
#         ...
# 124    TLSv1.2
# 125    TLSv1.2
# 137    TLSv1.2
# 145    TLSv1.2
# 147    TLSv1.2
# Name: Protocol, Length: 72, dtype: object

# %%
SSDataset1 = SSlDataset1.iloc[1:9]
SSDataset1
# Out:
#     No.      Time         Source    Destination Protocol  Length  \
# 25  282  3.971079  192.168.42.57    23.111.9.35  TLSv1.2     571
# 27  420  4.143166    23.111.9.35  192.168.42.57  TLSv1.2    1514
# 28  424  4.183122    23.111.9.35  192.168.42.57  TLSv1.2    1514
# 29  450  4.311076    23.111.9.35  192.168.42.57  TLSv1.2    1514
# 30  463  4.386124    23.111.9.35  192.168.42.57  TLSv1.2    1514
# 31  482  4.471248    23.111.9.35  192.168.42.57  TLSv1.2     446
# 32  484  4.481689  192.168.42.57    23.111.9.35  TLSv1.2     180
# 33  485  4.482107  192.168.42.57    23.111.9.35  TLSv1.2     153
#
#                                                  Info
# 25                                       Client Hello
# 27                                       Server Hello
# 28                                       Server Hello
# 29     Certificate [TCP segment of a reassembled PDU]
# 30     Certificate [TCP segment of a reassembled PDU]
# 31  Certificate Status, Server Key Exchange, Serve...
# ...

# %%
SSDataset2 = SSlDataset2.iloc[1:6]
SSDataset2
# Out:
#     No.       Time         Source    Destination Protocol  Length  \
# 36  659  17.037166  192.168.43.63  13.234.159.72  TLSv1.2     583
# 37  684  17.059165  13.234.159.72  192.168.43.63  TLSv1.2    1514
# 38  697  17.074081  13.234.159.72  192.168.43.63  TLSv1.2     680
# 39  701  17.078898  192.168.43.63  13.234.159.72  TLSv1.2     192
# 40  702  17.079561  192.168.43.63  13.234.159.72  TLSv1.2     785
#
#                                                  Info
# 36                                       Client Hello
# 37                                       Server Hello
# 38  Certificate, Server Key Exchange, Server Hello...
# 39  Client Key Exchange, Change Cipher Spec, Encry...
# 40                                   Application Data

# %%
SSDataset3 = SSlDataset3.iloc[1:8]
SSDataset3
# Out:
#     No.      Time         Source    Destination Protocol  Length  \
# 19  245  4.386489  192.168.43.63  114.29.220.99  TLSv1.2     571
# 20  248  4.482435  192.168.43.63  114.29.220.99  TLSv1.2     571
# 21  255  4.547468  114.29.220.99  192.168.43.63  TLSv1.2    1224
# 22  259  4.560372  114.29.220.99  192.168.43.63  TLSv1.2     587
# 23  261  4.561770  114.29.220.99  192.168.43.63  TLSv1.2     396
# 24  269  4.569755  192.168.43.63  114.29.220.99  TLSv1.2     180
# 25  273  4.571073  192.168.43.63  114.29.220.99  TLSv1.2    1112
#
#                                                  Info
# 19                                       Client Hello
# 20                                       Client Hello
# 21                          Server Hello, Certificate
# 22                                 Certificate Status
# 23             Server Key Exchange, Server Hello Done
# 24  Client Key Exchange, Change Cipher Spec, Encry...
# 25                                   Application Data

# %%
SSlDataset1['Info'].value_counts()[:6]
# Out:
# Application Data                                                        390
# Client Hello                                                            131
# Change Cipher Spec, Application Data                                     71
# Client Key Exchange, Change Cipher Spec, Encrypted Handshake Message     48
# Encrypted Alert                                                          40
# Continuation Data                                                        15
# Name: Info, dtype: int64

# %%
SSlDataset2['Info'].value_counts()[:6]
# Out:
# Application Data [TCP segment of a reassembled PDU]              36
# Application Data                                                 28
# Client Hello                                                      7
# Encrypted Alert                                                   6
# Ignored Unknown Record                                            5
# Server Hello, Change Cipher Spec, Encrypted Handshake Message     4
# Name: Info, dtype: int64

# %%
SSlDataset3['Info'].value_counts()[:6]
# Out:
# Application Data                                                        39
# Client Hello                                                             9
# Client Key Exchange, Change Cipher Spec, Encrypted Handshake Message     6
# Encrypted Handshake Message                                              3
# Change Cipher Spec                                                       3
# Server Key Exchange, Server Hello Done                                   3
# Name: Info, dtype: int64

# %%
SSlDataset1['Info'].value_counts()[:6].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
SSlDataset2['Info'].value_counts()[:6].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
SSlDataset3['Info'].value_counts()[:6].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.plot(SSDataset1['Time'],SSDataset1['Info'])
plt.ylabel('Transitions Of SSL Handshake')
plt.xlabel('Time')
plt.title('SSL Protocol Analysis')
plt.show()

# %%
plt.plot(SSDataset2['Time'],SSDataset2['Info'])
plt.ylabel('Transitions Of SSL Handshake')
plt.xlabel('Time')
plt.title('SSL Protocol Analysis')
plt.show()

# %%
plt.plot(SSDataset3['Time'],SSDataset3['Info'])
plt.ylabel('Transitions Of SSL Handshake')
plt.xlabel('Time')
plt.title('SSL Protocol Analysis')
plt.show()
